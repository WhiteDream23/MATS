# %% [markdown]
# # Example for fitting Experimental Spectra using MATS
# This example fits experimental Oxygen A-Band Spectra.  The provided code loads appropriate packages, defines the spectra and Dataset, generated parameter and baseline linelists, and fits the data.  This example also highlights the weighting options currently available in MATS.
#
# ## Load Relevant Packages

# %%
import numpy as np
import pandas as pd
import os, sys
import matplotlib.pyplot as plt
from matplotlib import gridspec
# %matplotlib inline
parent_dir = os.path.abspath('../../')
sys.path.append(parent_dir)
import MATS

import seaborn as sns
sns.set_style("whitegrid")
sns.set_style("ticks")
sns.set_context("poster")
# Out:
# HAPI version: 1.2.2.0
# To get the most up-to-date version please check http://hitran.org/hapi
# ATTENTION: Python versions of partition sums from TIPS-2021 are now available in HAPI code
#
#            MIT license: Copyright 2021 HITRAN team, see more at http://hitran.org.
#
#            If you use HAPI in your research or software development,
#            please cite it using the following reference:
#            R.V. Kochanov, I.E. Gordon, L.S. Rothman, P. Wcislo, C. Hill, J.S. Wilzewski,
#            HITRAN Application Programming Interface (HAPI): A comprehensive approach
#            to working with spectroscopic data, J. Quant. Spectrosc. Radiat. Transfer 177, 15-30 (2016)
#            DOI: 10.1016/j.jqsrt.2016.03.005
#
#            ATTENTION: This is the core version of the HITRAN Application Programming Interface.
#                       For more efficient implementation of the absorption coefficient routine,
#                       as well as for new profiles, parameters and other functional,
#                       please consider using HAPI2 extension library.
#                       HAPI2 package is available at http://github.com/hitranonline/hapi2

# %% [markdown]
# ## Define Spectrum Instances
#
# For experimental spectra, spectra are loaded from files by instantiating instances of the spectrum class.
#
# Before generating MATS.Spectrum objects from your experimental data, it is helpful to set some variables for terms that will be used in all of the MATS.Spectrum objects or throughout the fitting. In this example the minimum intensity threshold for simulation (IntensityThreshold), the minimum line intensity of lines fit in the analysis (Fit_Intensity), the order of the polynomial used in the baseline fits, and the names of columns used for the absorption, frequency, pressure, temperature, and statistics column data are defined at the top of the example.  The minimum intensity threshold for simulation will only simulate lines with an intensity above this threshold, where the minimum fit intensity defines the line intensity threshold necessary to allow parameters for that line to be varied in the fits.
#
# 4 instances of the MATS.Spectrum class are instantiated from 4 experimental spectra. In the class instantiation, the mole fraction of the oxygen sample used is defined, the etalon amplitude and period are defined, the polynomial order of the baseline is defined, the sample is confirmed to be at natural abundance, the diluent is set to air, and the columns defined for pressure, temperature, frequency, and absorbance data are set.
#
# The MATS.Spectrum.plot_wave_alpha() function can be called to plot any of the spectra.

# %%
#Generic Fit Parameters
wave_range = 1.5 #range outside of experimental x-range to simulate
IntensityThreshold = 1e-30 #intensities must be above this value to be simulated
Fit_Intensity = 1e-24 #intensities must be above this value for the line to be fit
order_baseline_fit = 1
tau_column = 'Corrected Tau (us)' # Mean tau/us
freq_column = 'Total Frequency (Detuning)' # Total Frequency /MHz
pressure_column = 'Cavity Pressure /Torr'
temperature_column = 'Cavity Temperature Side 2 /C'
tau_stats_column = 'tau rel. std. dev./%'


#Define all Spectra individually
spec_1 = MATS.Spectrum('190510_2per_43_forfit', 
                        molefraction = { 7 :0.01949}, natural_abundance = True, diluent = 'air', 
                        etalons = {1:[0.001364, 1.271443]}, baseline_order = 1, 
                        input_freq = True, frequency_column = freq_column,
                        input_tau = True, tau_column = tau_column, tau_stats_column = tau_stats_column, 
                        pressure_column = pressure_column, temperature_column = temperature_column, 
                        nominal_temperature = 296, x_shift = 0.00)
spec_2 = MATS.Spectrum('190510_2per_55_forfit', 
                        molefraction = { 7 : 0.01949}, natural_abundance = True, diluent = 'air', 
                        etalons = {1:[0.001364, 1.271443]}, baseline_order = 1, 
                        input_freq = True, frequency_column = freq_column,
                        input_tau = True, tau_column = tau_column, tau_stats_column = tau_stats_column, 
                        pressure_column = pressure_column, temperature_column = temperature_column, 
                        nominal_temperature = 296, x_shift = 0.00)
spec_3 = MATS.Spectrum('190513_2per_82_forfit', 
                        molefraction = { 7 :0.01949}, natural_abundance = True, diluent = 'air', 
                        etalons = {1:[0.001364, 1.271443]}, baseline_order = 1, 
                        input_freq = True, frequency_column = freq_column,
                        input_tau = True, tau_column = tau_column, tau_stats_column = tau_stats_column, 
                        pressure_column = pressure_column, temperature_column = temperature_column, 
                        nominal_temperature = 296, x_shift = 0.00)
spec_4 = MATS.Spectrum('190514_2per_126_forfit', 
                        molefraction = { 7 :0.01949}, natural_abundance = True, diluent = 'air', 
                        etalons = {1:[0.001364, 1.271443]}, baseline_order = 1, 
                        input_freq = True, frequency_column = freq_column,
                        input_tau = True, tau_column = tau_column, tau_stats_column = tau_stats_column, 
                        pressure_column = pressure_column, temperature_column = temperature_column, 
                        nominal_temperature = 296, x_shift = 0.00)



spec_1.plot_wave_alpha()

# %% [markdown]
# ## Generate a Dataset
#
# An initial line shape parameter line list needs to be provided.  This is stored as a dataframe after reading in from a .csv file. The LoadLineListData class can be used to import line lists that are within the Linelist folder in MATS, example line lists are provided.  However, a line list can also be read in from any .csv file of the appropriate format by using the pandas read_csv(filename) function.
#
# The next step is to combine all desired MATS Spectrum objects into a MATS Dataset object, where we give the dataset a name and define the line shape parameter line list to use.  This allows for initial consistency checks between the experimental spectra and the initial line lists.
#
# The MATS Dataset class contains a function to generate a baseline line list, analogous to the one for the parameter line list done outside of this example, based on the order of the baseline fit, etalons, molecules, x-shift parameters, and segments as defined by both the spectrum and dataset objects.

# %%
from MATS.linelistdata import linelistdata

# %%
#Read in linelists
PARAM_LINELIST = linelistdata['O2_ABand_Drouin_2017_linelist']
#Add all spectrum to a Dataset object
SPECTRA = MATS.Dataset([spec_1, spec_2, spec_3, spec_4], 'Line Intensity',PARAM_LINELIST)

#Generate Baseline Parameter list based on number of etalons in spectra definitions and baseline order
BASE_LINELIST = SPECTRA.generate_baseline_paramlist()

# %% [markdown]
# ## Generate Fit Parameter Files
#
# The next section of code uses the MATS Generate_FitParam_File class to define what line shape to use for the initial fits, whether to use line mixing, the minimum line intensity to fit a line, mimimum intensity to included in the simulation, and for each line parameter whether that parameter is going to be constrained across all spectra or whether there will be a parameter for each spectrum (multi-spectrum vs single-spectrum fits) on a parameter by parameter basis. In the example below, the SDVP line profile without line mixing will be used to fit lines with line intensities greater than 1e-24 and the line centers and line intensities will be allowed to float for each line, while all other lines are constrained across all spectra in the dataset. The additional_columns parameter allows for inclusion of additional columns in the line shape parameter line list to be included in the output file.
#
# The next step is to generate fit parameter and baseline line lists that include columns that specify whether that parameter should be varied during fitting, in addition to adding error columns for the fit error for each parameter. For the following example the line centers, line intensities, collisional half-widths, and speed-dependent broadening terms will be floated for all main oxygen isotopes for lines where the line intensity is greater than 1e-24. Additionally, the baseline terms will float, as will the etalon amplitude and phase.
#
# These functions will generate .csv files corresponding to these selections, which are read in by the MATS Fit_DataSet class instantiation. This means that edits can be made manually to the .csv files or by reading in the .csv, editing, and resaving before the next code segment is run.

# %%
FITPARAMS = MATS.Generate_FitParam_File(SPECTRA, PARAM_LINELIST, BASE_LINELIST, lineprofile = 'SDVP', linemixing = False, 
                                  fit_intensity = Fit_Intensity, threshold_intensity = IntensityThreshold, sim_window = wave_range,
                                  nu_constrain = True, sw_constrain = False, gamma0_constrain = True, delta0_constrain = True, 
                                   aw_constrain = True, as_constrain = True, 
                                   nuVC_constrain = True, eta_constrain =True, linemixing_constrain = True,
                                    additional_columns = ['trans_id', 'local_lower_quanta', 'm'])

FITPARAMS.generate_fit_param_linelist_from_linelist(vary_nu = {7:{1:True, 2:False, 3:False}}, vary_sw = {7:{1:True, 2:False, 3:False}},
                                                    vary_gamma0 = {7:{1: True, 2:False, 3: False}, 1:{1:False}}, vary_n_gamma0 = {7:{1:True}}, 
                                                    vary_delta0 = {7:{1: True, 2:False, 3: False}, 1:{1:False}}, vary_n_delta0 = {7:{1:True}}, 
                                                    vary_aw = {7:{1: True, 2:False, 3: False}, 1:{1:False}}, vary_n_gamma2 = {7:{1:False}}, 
                                                    vary_as = {}, vary_n_delta2 = {7:{1:False}}, 
                                                    vary_nuVC = {7:{1:False}}, vary_n_nuVC = {7:{1:False}},
                                                    vary_eta = {}, vary_linemixing = {7:{1:False}})

FITPARAMS.generate_fit_baseline_linelist(vary_baseline = True, vary_molefraction = {7:False, 1:False}, vary_xshift = False, 
                                      vary_etalon_amp= True, vary_etalon_period= False, vary_etalon_phase= True)
# Out:
#                  Segment Number  Pressure  Pressure_err  Pressure_vary  \
# Spectrum Number
# 1                             1  0.079111           0.0          False
# 2                             1  0.065558           0.0          False
# 3                             1  0.046017           0.0          False
# 4                             1  0.024884           0.0          False
#
#                  Temperature  Temperature_err  Temperature_vary  x_shift  \
# Spectrum Number
# 1                 297.903746              0.0             False      0.0
# 2                 297.908245              0.0             False      0.0
# 3                 297.876303              0.0             False      0.0
# 4                 297.864910              0.0             False      0.0
#
#                  x_shift_err  x_shift_vary  ...  baseline_b_vary  \
# Spectrum Number                             ...
# 1                        0.0         False  ...             True
# 2                        0.0         False  ...             True
# 3                        0.0         False  ...             True
# 4                        0.0         False  ...             True
#
#                  etalon_1_amp  etalon_1_amp_err  etalon_1_amp_vary  \
# Spectrum Number
# 1                    0.001364               0.0               True
# 2                    0.001364               0.0               True
# 3                    0.001364               0.0               True
# 4                    0.001364               0.0               True
#
#                  etalon_1_period  etalon_1_period_err  etalon_1_period_vary  \
# Spectrum Number
# 1                       1.271443                  0.0                 False
# 2                       1.271443                  0.0                 False
# 3                       1.271443                  0.0                 False
# 4                       1.271443                  0.0                 False
#
#                  etalon_1_phase  etalon_1_phase_err  etalon_1_phase_vary
# Spectrum Number
# 1                           0.0                 0.0                 True
# 2                           0.0                 0.0                 True
# 3                           0.0                 0.0                 True
# 4                           0.0                 0.0                 True
#
# [4 rows x 28 columns]

# %% [markdown]
# ## Fit Dataset
#
# Instantiating the MATS Fit_DataSet class reads in the information from the baseline and parameter linelists generated in the previous step. It also allows for limits to be placed on the parameters, so that they don’t result in divergent solutions. The example below includes several limits including limiting the line center to be within 0.1 cm-1 of the initial guess and the Line intensity to be within a factor of 2 of the intial guess. Placing limits on the parameters can be restrictive on the solution and cause the fit to not converge or return NaN for the standard error if it doesn’t allow for a local minima to be found.
#
# The Fit Dataset also allows for the option to weight_spectra, currently this is set to False.  Later in this example we will explore using weights in fitting.
#
# The next step is to generate the lmfit params dictionary object through the MATS.Fit_DataSet.generate_params() function. This translates baseline and parameter line list .csv files into the lmfit parameter dictionary that is used in the fits. After the parameters object is generated you can use the keys to set values and impose constraints on individual parameters, if desired. While this is not coded in the MATS toolkit, it is incredibly powerful as it lets you define min, max, vary, and expression values for any parameter. In the example below, two additional constraints are imposed on specific fit parameters. The first constrains all speed-dependent width parameters to be between the values of 0.01 and 0.25 and the second forces the amplitude of the etalon to be constant across all spectra.
#
# The params file is then used to fit the spectra in the dataset using the MATS.Fit_DataSet.fit_data() function, where the result is a lmfit result object. The lmft prettyprint function prints the parameter fit results. Included below is an  prettyprint output that not only shows the fit result values and standard errors, but also highlights that constraints were imposed on the SD_gamma (speed dependent broadening) parameters and an expression was imposed on the etalon_amplitudes. It also shows that the there is a line intensity reported for every line (suffix number) and spectrum (after sw_) as the line intensities were not constrained to global fits. The reported sw shows that the fitted line intensity value is scaled by the minimum fit value. This aids in the fitting as line intensities are so much smaller than other values.
#
# The last segment of code provides residual plots and updates residuals through the MATS.fit_data.residual_analysis() and MATS.Dataset.plot_model_residuals() functions, updates the parameter and baseline line lists through MATS.fit_data.update_params(), and generates a summary file with the fit results using MATS.Dataset.plot_model_residuals().

# %%
fit_data = MATS.Fit_DataSet(SPECTRA,'Baseline_LineList', 'Parameter_LineList', minimum_parameter_fit_intensity = Fit_Intensity, weight_spectra = False,
                baseline_limit = False, baseline_limit_factor = 10, 
                molefraction_limit = False, molefraction_limit_factor = 1.1, 
                etalon_limit = False, etalon_limit_factor = 2, #phase is constrained to +/- 2pi, 
                x_shift_limit = False, x_shift_limit_magnitude = 0.5, 
                nu_limit = True, nu_limit_magnitude = 0.1, 
                sw_limit = True, sw_limit_factor = 2, 
                gamma0_limit = False, gamma0_limit_factor = 3, n_gamma0_limit= False, n_gamma0_limit_factor = 50, 
                delta0_limit = False, delta0_limit_factor = 2, n_delta0_limit = False, n_delta0_limit_factor = 50, 
                SD_gamma_limit = False, SD_gamma_limit_factor = 2, n_gamma2_limit = False, n_gamma2_limit_factor = 50, 
                SD_delta_limit = False, SD_delta_limit_factor = 50, n_delta2_limit = False, n_delta2_limit_factor = 50, 
                nuVC_limit = False, nuVC_limit_factor = 2, n_nuVC_limit = False, n_nuVC_limit_factor = 50, 
                eta_limit = False, eta_limit_factor = 50, linemixing_limit = False, linemixing_limit_factor = 50)
params = fit_data.generate_params()



for param in params:
    if 'SD_gamma' in param:
        if params[param].vary == True:
            params[param].set(min = 0.01, max = 0.25)
    if 'etalon_1_amp' in param:
        if param != 'etalon_1_amp_1_1':
            params[param].set(expr='etalon_1_amp_1_1')
            
        


result = fit_data.fit_data(params, wing_cutoff = 25)
print (result.params.pretty_print())

fit_data.residual_analysis(result, indv_resid_plot=True)
fit_data.update_params(result)
SPECTRA.generate_summary_file(save_file = True)
SPECTRA.plot_model_residuals()
# Out:
# Name                    Value      Min      Max   Stderr     Vary     Expr Brute_Step
# Pressure_1_1          0.07911     -inf      inf        0    False     None     None
# Pressure_2_1          0.06556     -inf      inf        0    False     None     None
# Pressure_3_1          0.04602     -inf      inf        0    False     None     None
# Pressure_4_1          0.02488     -inf      inf        0    False     None     None
# SD_delta_air_line_0         0     -inf      inf        0    False     None     None
# SD_delta_air_line_1         0     -inf      inf        0    False     None     None
# SD_delta_air_line_2         0     -inf      inf        0    False     None     None
# SD_delta_air_line_3         0     -inf      inf        0    False     None     None
# SD_delta_air_line_4         0     -inf      inf        0    False     None     None
# SD_gamma_air_line_0       0.1     -inf      inf        0    False     None     None
# SD_gamma_air_line_1    0.1123     0.01     0.25 0.0009811     True     None     None
# SD_gamma_air_line_2    0.1306     0.01     0.25 0.001314     True     None     None
# SD_gamma_air_line_3       0.1     -inf      inf        0    False     None     None
# SD_gamma_air_line_4      0.09     -inf      inf        0    False     None     None
# Temperature_1_1         297.9     -inf      inf        0    False     None     None
# Temperature_2_1         297.9     -inf      inf        0    False     None     None
# Temperature_3_1         297.9     -inf      inf        0    False     None     None
# Temperature_4_1         297.9     -inf      inf        0    False     None     None
# baseline_a_1_1          2.958     -inf      inf 0.000125     True     None     None
# baseline_a_2_1          2.959     -inf      inf 0.0001204     True     None     None
# baseline_a_3_1          2.953     -inf      inf 0.0001224     True     None     None
# baseline_a_4_1           2.95     -inf      inf 0.0001269     True     None     None
# baseline_b_1_1       0.002028     -inf      inf 0.0001358     True     None     None
# baseline_b_2_1       0.001987     -inf      inf 0.0001301     True     None     None
# baseline_b_3_1       0.001991     -inf      inf 0.0001368     True     None     None
# baseline_b_4_1       0.001752     -inf      inf 0.0001533     True     None     None
# delta0_air_line_0    -0.007977     -inf      inf        0    False     None     None
# delta0_air_line_1    -0.00781     -inf      inf 7.703e-05     True     None     None
# delta0_air_line_2    -0.00777     -inf      inf 0.000115     True     None     None
# delta0_air_line_3    -0.008568     -inf      inf        0    False     None     None
# delta0_air_line_4    -0.008741     -inf      inf        0    False     None     None
# eta_air_line_0              0     -inf      inf        0    False     None     None
# eta_air_line_1              0     -inf      inf        0    False     None     None
# eta_air_line_2              0     -inf      inf        0    False     None     None
# eta_air_line_3              0     -inf      inf        0    False     None     None
# eta_air_line_4              0     -inf      inf        0    False     None     None
# etalon_1_amp_1_1     0.001652     -inf      inf 4.667e-05     True     None     None
# etalon_1_amp_2_1     0.001652     -inf      inf 4.667e-05    False etalon_1_amp_1_1     None
# etalon_1_amp_3_1     0.001652     -inf      inf 4.667e-05    False etalon_1_amp_1_1     None
# etalon_1_amp_4_1     0.001652     -inf      inf 4.667e-05    False etalon_1_amp_1_1     None
# etalon_1_period_1_1     1.271     -inf      inf        0    False     None     None
# etalon_1_period_2_1     1.271     -inf      inf        0    False     None     None
# etalon_1_period_3_1     1.271     -inf      inf        0    False     None     None
# etalon_1_period_4_1     1.271     -inf      inf        0    False     None     None
# etalon_1_phase_1_1     -0.738     -inf      inf  0.05719     True     None     None
# etalon_1_phase_2_1    -0.4759     -inf      inf  0.05271     True     None     None
# etalon_1_phase_3_1     -1.403     -inf      inf  0.05697     True     None     None
# etalon_1_phase_4_1      -1.66     -inf      inf  0.05647     True     None     None
# gamma0_air_line_0        0.04     -inf      inf        0    False     None     None
# gamma0_air_line_1     0.04487     -inf      inf 5.814e-05     True     None     None
# gamma0_air_line_2     0.04331     -inf      inf 8.789e-05     True     None     None
# gamma0_air_line_3        0.04     -inf      inf        0    False     None     None
# gamma0_air_line_4        0.04     -inf      inf        0    False     None     None
# molefraction_O2_1_1   0.01949     -inf      inf        0    False     None     None
# molefraction_O2_2_1   0.01949     -inf      inf        0    False     None     None
# molefraction_O2_3_1   0.01949     -inf      inf        0    False     None     None
# molefraction_O2_4_1   0.01949     -inf      inf        0    False     None     None
# nuVC_air_line_0             0     -inf      inf        0    False     None     None
# nuVC_air_line_1             0     -inf      inf        0    False     None     None
# nuVC_air_line_2             0     -inf      inf        0    False     None     None
# nuVC_air_line_3             0     -inf      inf        0    False     None     None
# nuVC_air_line_4             0     -inf      inf        0    False     None     None
# nu_line_0            1.315e+04 1.315e+04 1.315e+04        0    False     None     None
# nu_line_1            1.316e+04 1.316e+04 1.316e+04 5.129e-06     True     None     None
# nu_line_2            1.316e+04 1.316e+04 1.316e+04 7.731e-06     True     None     None
# nu_line_3            1.316e+04 1.316e+04 1.316e+04        0    False     None     None
# nu_line_4            1.316e+04 1.316e+04 1.316e+04        0    False     None     None
# sw_1_line_0             4.369    2.185    8.738        0    False     None     None
# sw_1_line_1             4.732      2.4    9.598 0.001016     True     None     None
# sw_1_line_2             3.086    1.562    6.246 0.000849     True     None     None
# sw_1_line_3             3.399      1.7    6.798        0    False     None     None
# sw_1_line_4             2.083    1.042    4.166        0    False     None     None
# sw_2_line_0             4.369    2.185    8.738        0    False     None     None
# sw_2_line_1              4.75      2.4    9.598 0.0008213     True     None     None
# sw_2_line_2             3.091    1.562    6.246 0.0008059     True     None     None
# sw_2_line_3             3.399      1.7    6.798        0    False     None     None
# sw_2_line_4             2.083    1.042    4.166        0    False     None     None
# sw_3_line_0             4.369    2.185    8.738        0    False     None     None
# sw_3_line_1             4.742      2.4    9.598 0.0008792     True     None     None
# sw_3_line_2             3.094    1.562    6.246 0.0008832     True     None     None
# sw_3_line_3             3.399      1.7    6.798        0    False     None     None
# sw_3_line_4             2.083    1.042    4.166        0    False     None     None
# sw_4_line_0             4.369    2.185    8.738        0    False     None     None
# sw_4_line_1             4.798      2.4    9.598 0.001365     True     None     None
# sw_4_line_2             3.117    1.562    6.246 0.001386     True     None     None
# sw_4_line_3             3.399      1.7    6.798        0    False     None     None
# sw_4_line_4             2.083    1.042    4.166        0    False     None     None
# x_shift_1_1                 0     -inf      inf        0    False     None     None
# x_shift_2_1                 0     -inf      inf        0    False     None     None
# x_shift_3_1                 0     -inf      inf        0    False     None     None
# x_shift_4_1                 0     -inf      inf        0    False     None     None
# y_air_line_0                0     -inf      inf        0    False     None     None
# y_air_line_1                0     -inf      inf        0    False     None     None
# y_air_line_2                0     -inf      inf        0    False     None     None
# y_air_line_3                0     -inf      inf        0    False     None     None
# y_air_line_4                0     -inf      inf        0    False     None     None
# None

# %% [markdown]
# Call to the MATS.Spectrum.fft_spectrum() function takes an FFT of the residuals. If we hadn’t included the etalon, the result of the fft_spectrum() functions would show a peak with the most abundant period being 1.271443 cm-1 and an amplitude of 0.001364, which were used as the initial guess for the etalon in the spectrum class definitions. The more etalon periods present in the spectral region being fit the more precise the etalon amplitude and frequency determined by the FFT will be.

# %%
spec_3.fft_spectrum()
# Out:
#     Period (cm)  Amplitude     Phase  Freq (cm-1)
# 0     14.621592   0.000276 -2.494217     0.068392
# 1      6.357214   0.000264  0.168994     0.157302
# 2      8.264378   0.000254 -0.072233     0.121001
# 3      9.535821   0.000204  0.014925     0.104868
# 4     10.807263   0.000187  2.457331     0.092530
# 5      8.900099   0.000181  2.839665     0.112358
# 6      1.271443   0.000181 -2.940173     0.786508
# 7      5.721492   0.000173  2.611611     0.174780
# 8     55.307760   0.000170 -3.085711     0.018081
# 9     13.985870   0.000170  0.392203     0.071501
# 10     2.542886   0.000170  0.003501     0.393254
# 11    17.164477   0.000166 -0.033242     0.058260
# 12    15.893034   0.000163 -2.131615     0.062921
# 13    22.250248   0.000161 -1.942538     0.044943
# 14     6.992935   0.000157  3.057083     0.143001
# 15    38.143283   0.000152  2.224205     0.026217
# 16    22.885970   0.000151  1.644234     0.043695
# 17    15.257313   0.000142  0.996410     0.065542
# 18    46.407660   0.000141  0.433590     0.021548
# 19    16.528756   0.000140  2.533365     0.060501
# 20    35.600397   0.000140  1.005113     0.028090
# E:\MATS\MATS-main\MATS\spectrum.py:429: RuntimeWarning: divide by zero encountered in divide
#   FFT['Freq (cm-1)'] = 1 / fft_freq
# E:\MATS\MATS-main\MATS\spectrum.py:434: RuntimeWarning: divide by zero encountered in divide
#   plt.plot(1 / fft_freq, fft_amplitude, '-')

# %% [markdown]
# ## Explore the Ability to Weight spectra
#
# Spectra can be weighted in two different ways, using the stats column defined for each spectrum or weighting the entire spectrum.  In the first example below, we use use the same code that was introduced previously, but set the weight_spectra variable in the Fit_Dataset definitions to True.  This weights the contribution to the solution at each point in each spectrum by 1/tau_stats_column.  If the tau_stats_column is not defined then this will default to the equal weights for all data points.

# %%
# Set-up for Fitting
  

fit_data = MATS.Fit_DataSet(SPECTRA,'Baseline_LineList', 'Parameter_LineList', minimum_parameter_fit_intensity = Fit_Intensity, weight_spectra = True,
                baseline_limit = False, baseline_limit_factor = 10, 
                molefraction_limit = False, molefraction_limit_factor = 1.1, 
                etalon_limit = False, etalon_limit_factor = 2, #phase is constrained to +/- 2pi, 
                x_shift_limit = False, x_shift_limit_magnitude = 0.5, 
                nu_limit = True, nu_limit_magnitude = 0.1, 
                sw_limit = True, sw_limit_factor = 2, 
                gamma0_limit = False, gamma0_limit_factor = 3, n_gamma0_limit= False, n_gamma0_limit_factor = 50, 
                delta0_limit = False, delta0_limit_factor = 2, n_delta0_limit = False, n_delta0_limit_factor = 50, 
                SD_gamma_limit = False, SD_gamma_limit_factor = 2, n_gamma2_limit = False, n_gamma2_limit_factor = 50, 
                SD_delta_limit = False, SD_delta_limit_factor = 50, n_delta2_limit = False, n_delta2_limit_factor = 50, 
                nuVC_limit = False, nuVC_limit_factor = 2, n_nuVC_limit = False, n_nuVC_limit_factor = 50, 
                eta_limit = False, eta_limit_factor = 50, linemixing_limit = False, linemixing_limit_factor = 50)
params = fit_data.generate_params()



for param in params:
    if 'SD_gamma' in param:
        if params[param].vary == True:
            params[param].set(min = 0.01, max = 0.25)
    if 'etalon_1_amp' in param:
        if param != 'etalon_1_amp_1_1':
            params[param].set(expr='etalon_1_amp_1_1')
            
        


result = fit_data.fit_data(params, wing_cutoff = 25)
print (result.params.pretty_print())

fit_data.residual_analysis(result, indv_resid_plot=True)
fit_data.update_params(result)
SPECTRA.generate_summary_file(save_file = True)
SPECTRA.plot_model_residuals()
# Out:
# Name                     Value      Min      Max   Stderr     Vary     Expr Brute_Step
# Pressure_1_1           0.07911     -inf      inf        0    False     None     None
# Pressure_2_1           0.06556     -inf      inf        0    False     None     None
# Pressure_3_1           0.04602     -inf      inf        0    False     None     None
# Pressure_4_1           0.02488     -inf      inf        0    False     None     None
# SD_delta_air_line_1          0     -inf      inf        0    False     None     None
# SD_delta_air_line_10         0     -inf      inf        0    False     None     None
# SD_delta_air_line_13         0     -inf      inf        0    False     None     None
# SD_delta_air_line_25         0     -inf      inf        0    False     None     None
# SD_delta_air_line_26         0     -inf      inf        0    False     None     None
# SD_gamma_air_line_1        0.1     -inf      inf        0    False     None     None
# SD_gamma_air_line_10    0.1068     0.01     0.25 0.001343     True     None     None
# SD_gamma_air_line_13     0.127     0.01     0.25 0.001586     True     None     None
# SD_gamma_air_line_25      0.09     -inf      inf        0    False     None     None
# SD_gamma_air_line_26       0.1     -inf      inf        0    False     None     None
# Temperature_1_1          297.9     -inf      inf        0    False     None     None
# Temperature_2_1          297.9     -inf      inf        0    False     None     None
# Temperature_3_1          297.9     -inf      inf        0    False     None     None
# Temperature_4_1          297.9     -inf      inf        0    False     None     None
# baseline_a_1_1           2.958     -inf      inf 9.774e-05     True     None     None
# baseline_a_2_1            2.96     -inf      inf 9.321e-05     True     None     None
# baseline_a_3_1           2.953     -inf      inf 9.688e-05     True     None     None
# baseline_a_4_1            2.95     -inf      inf 9.545e-05     True     None     None
# baseline_b_1_1        0.001966     -inf      inf 0.0001051     True     None     None
# baseline_b_2_1        0.001883     -inf      inf 9.923e-05     True     None     None
# baseline_b_3_1        0.001956     -inf      inf 0.0001091     True     None     None
# baseline_b_4_1        0.001799     -inf      inf 0.000115     True     None     None
# delta0_air_line_1     -0.007977     -inf      inf        0    False     None     None
# delta0_air_line_10    -0.007462     -inf      inf 0.0001146     True     None     None
# delta0_air_line_13    -0.007644     -inf      inf 0.0001419     True     None     None
# delta0_air_line_25    -0.008741     -inf      inf        0    False     None     None
# delta0_air_line_26    -0.008568     -inf      inf        0    False     None     None
# eta_air_line_1               0     -inf      inf        0    False     None     None
# eta_air_line_10              0     -inf      inf        0    False     None     None
# eta_air_line_13              0     -inf      inf        0    False     None     None
# eta_air_line_25              0     -inf      inf        0    False     None     None
# eta_air_line_26              0     -inf      inf        0    False     None     None
# etalon_1_amp_1_1      0.001615     -inf      inf 3.581e-05     True     None     None
# etalon_1_amp_2_1      0.001615     -inf      inf 3.581e-05    False etalon_1_amp_1_1     None
# etalon_1_amp_3_1      0.001615     -inf      inf 3.581e-05    False etalon_1_amp_1_1     None
# etalon_1_amp_4_1      0.001615     -inf      inf 3.581e-05    False etalon_1_amp_1_1     None
# etalon_1_period_1_1      1.271     -inf      inf        0    False     None     None
# etalon_1_period_2_1      1.271     -inf      inf        0    False     None     None
# etalon_1_period_3_1      1.271     -inf      inf        0    False     None     None
# etalon_1_period_4_1      1.271     -inf      inf        0    False     None     None
# etalon_1_phase_1_1     -0.7705     -inf      inf  0.04582     True     None     None
# etalon_1_phase_2_1      -0.516     -inf      inf   0.0415     True     None     None
# etalon_1_phase_3_1      -1.411     -inf      inf   0.0474     True     None     None
# etalon_1_phase_4_1      -1.673     -inf      inf  0.04346     True     None     None
# gamma0_air_line_1         0.04     -inf      inf        0    False     None     None
# gamma0_air_line_10     0.04463     -inf      inf 5.569e-05     True     None     None
# gamma0_air_line_13      0.0432     -inf      inf 7.788e-05     True     None     None
# gamma0_air_line_25        0.04     -inf      inf        0    False     None     None
# gamma0_air_line_26        0.04     -inf      inf        0    False     None     None
# molefraction_O2_1_1    0.01949     -inf      inf        0    False     None     None
# molefraction_O2_2_1    0.01949     -inf      inf        0    False     None     None
# molefraction_O2_3_1    0.01949     -inf      inf        0    False     None     None
# molefraction_O2_4_1    0.01949     -inf      inf        0    False     None     None
# nuVC_air_line_1              0     -inf      inf        0    False     None     None
# nuVC_air_line_10             0     -inf      inf        0    False     None     None
# nuVC_air_line_13             0     -inf      inf        0    False     None     None
# nuVC_air_line_25             0     -inf      inf        0    False     None     None
# nuVC_air_line_26             0     -inf      inf        0    False     None     None
# nu_line_1             1.315e+04 1.315e+04 1.315e+04        0    False     None     None
# nu_line_10            1.316e+04 1.316e+04 1.316e+04 7.21e-06     True     None     None
# nu_line_13            1.316e+04 1.316e+04 1.316e+04 9.067e-06     True     None     None
# nu_line_25            1.316e+04 1.316e+04 1.316e+04        0    False     None     None
# nu_line_26            1.316e+04 1.316e+04 1.316e+04        0    False     None     None
# sw_1_line_1               4.37    2.185     8.74        0    False     None     None
# sw_1_line_10              4.73    2.366    9.465 0.001485     True     None     None
# sw_1_line_13             3.086    1.543    6.173 0.0009328     True     None     None
# sw_1_line_25              2.08     1.04     4.16        0    False     None     None
# sw_1_line_26               3.4      1.7      6.8        0    False     None     None
# sw_2_line_1               4.37    2.185     8.74        0    False     None     None
# sw_2_line_10             4.748    2.375      9.5  0.00114     True     None     None
# sw_2_line_13             3.091    1.545    6.182 0.0009515     True     None     None
# sw_2_line_25              2.08     1.04     4.16        0    False     None     None
# sw_2_line_26               3.4      1.7      6.8        0    False     None     None
# sw_3_line_1               4.37    2.185     8.74        0    False     None     None
# sw_3_line_10             4.742    2.371    9.485 0.001342     True     None     None
# sw_3_line_13             3.094    1.547    6.188 0.001069     True     None     None
# sw_3_line_25              2.08     1.04     4.16        0    False     None     None
# sw_3_line_26               3.4      1.7      6.8        0    False     None     None
# sw_4_line_1               4.37    2.185     8.74        0    False     None     None
# sw_4_line_10             4.797    2.399    9.597 0.001751     True     None     None
# sw_4_line_13             3.117    1.559    6.234  0.00146     True     None     None
# sw_4_line_25              2.08     1.04     4.16        0    False     None     None
# sw_4_line_26               3.4      1.7      6.8        0    False     None     None
# x_shift_1_1                  0     -inf      inf        0    False     None     None
# x_shift_2_1                  0     -inf      inf        0    False     None     None
# x_shift_3_1                  0     -inf      inf        0    False     None     None
# x_shift_4_1                  0     -inf      inf        0    False     None     None
# y_air_line_1                 0     -inf      inf        0    False     None     None
# y_air_line_10                0     -inf      inf        0    False     None     None
# y_air_line_13                0     -inf      inf        0    False     None     None
# y_air_line_25                0     -inf      inf        0    False     None     None
# y_air_line_26                0     -inf      inf        0    False     None     None
# None

# %% [markdown]
# The other option for weighting, that can be used with or without the point by point weighting, is to weight each spectrum by setting the spectrum weight value.  The default for each spectrum is 1.  This value can be set through the weight parameter in the spectrum definition or by using the set_weight(value) command, which is shown below.
#
# For all weighting options, the residuals are adjusted by the weight factors.  For this example, where the spec_1 is given a weight of 0 this effectively removes spec_1 from the solution consideration.  Note that setting the weight to 0 will return a warning message.

# %%
# Change the Weights of spectra and use stats column
spec_1.set_weight(1)
spec_2.set_weight(0.1)
spec_3.set_weight(0.1)
spec_4.set_weight(0.01)
FITPARAMS = MATS.Generate_FitParam_File(SPECTRA, PARAM_LINELIST, BASE_LINELIST, lineprofile = 'SDVP', linemixing = False, 
                                  fit_intensity = Fit_Intensity, threshold_intensity = IntensityThreshold, sim_window = wave_range,
                                  nu_constrain = False, sw_constrain = False, gamma0_constrain = True, delta0_constrain = True, 
                                   aw_constrain = True, as_constrain = True, 
                                   nuVC_constrain = True, eta_constrain =True, linemixing_constrain = True)
                                  #additional_columns = ['trans_id', 'local_lower_quanta', 'm'])

FITPARAMS.generate_fit_param_linelist_from_linelist(vary_nu = {7:{1:True, 2:False, 3:False}}, vary_sw = {7:{1:True, 2:False, 3:False}},
                                                    vary_gamma0 = {7:{1: True, 2:False, 3: False}, 1:{1:False}}, vary_n_gamma0 = {7:{1:True}}, 
                                                    vary_delta0 = {7:{1: False, 2:False, 3: False}, 1:{1:False}}, vary_n_delta0 = {7:{1:True}}, 
                                                    vary_aw = {7:{1: True, 2:False, 3: False}, 1:{1:False}}, vary_n_gamma2 = {7:{1:False}}, 
                                                    vary_as = {}, vary_n_delta2 = {7:{1:False}}, 
                                                    vary_nuVC = {7:{1:False}}, vary_n_nuVC = {7:{1:False}},
                                                    vary_eta = {}, vary_linemixing = {7:{1:False}})

FITPARAMS.generate_fit_baseline_linelist(vary_baseline = True, vary_molefraction = {7:False, 1:False}, vary_xshift = True, 
                                      vary_etalon_amp= True, vary_etalon_period= False, vary_etalon_phase= True)


fit_data = MATS.Fit_DataSet(SPECTRA,'Baseline_LineList', 'Parameter_LineList', minimum_parameter_fit_intensity = Fit_Intensity, weight_spectra = True,
                baseline_limit = False, baseline_limit_factor = 10, 
                molefraction_limit = False, molefraction_limit_factor = 1.1, 
                etalon_limit = False, etalon_limit_factor = 2, #phase is constrained to +/- 2pi, 
                x_shift_limit = False, x_shift_limit_magnitude = 0.5, 
                nu_limit = True, nu_limit_magnitude = 0.1, 
                sw_limit = True, sw_limit_factor = 2, 
                gamma0_limit = False, gamma0_limit_factor = 3, n_gamma0_limit= False, n_gamma0_limit_factor = 50, 
                delta0_limit = False, delta0_limit_factor = 2, n_delta0_limit = False, n_delta0_limit_factor = 50, 
                SD_gamma_limit = False, SD_gamma_limit_factor = 2, n_gamma2_limit = False, n_gamma2_limit_factor = 50, 
                SD_delta_limit = False, SD_delta_limit_factor = 50, n_delta2_limit = False, n_delta2_limit_factor = 50, 
                nuVC_limit = False, nuVC_limit_factor = 2, n_nuVC_limit = False, n_nuVC_limit_factor = 50, 
                eta_limit = False, eta_limit_factor = 50, linemixing_limit = False, linemixing_limit_factor = 50)
params = fit_data.generate_params()



for param in params:
    if 'SD_gamma' in param:
        if params[param].vary == True:
            params[param].set(min = 0.01, max = 0.25)
    if 'etalon_1_amp' in param:
        if param != 'etalon_1_amp_1_1':
            params[param].set(expr='etalon_1_amp_1_1')
            
        


result = fit_data.fit_data(params, wing_cutoff = 25)
print (result.params.pretty_print())

fit_data.residual_analysis(result, indv_resid_plot=True)
fit_data.update_params(result)
SPECTRA.generate_summary_file(save_file = True)
SPECTRA.plot_model_residuals()
# Out:
# Name                     Value      Min      Max   Stderr     Vary     Expr Brute_Step
# Pressure_1_1           0.07911     -inf      inf        0    False     None     None
# Pressure_2_1           0.06556     -inf      inf        0    False     None     None
# Pressure_3_1           0.04602     -inf      inf        0    False     None     None
# Pressure_4_1           0.02488     -inf      inf        0    False     None     None
# SD_delta_air_line_1          0     -inf      inf        0    False     None     None
# SD_delta_air_line_10         0     -inf      inf        0    False     None     None
# SD_delta_air_line_13         0     -inf      inf        0    False     None     None
# SD_delta_air_line_25         0     -inf      inf        0    False     None     None
# SD_delta_air_line_26         0     -inf      inf        0    False     None     None
# SD_gamma_air_line_1        0.1     -inf      inf        0    False     None     None
# SD_gamma_air_line_10    0.1022     0.01     0.25 0.001473     True     None     None
# SD_gamma_air_line_13    0.1261     0.01     0.25 0.001378     True     None     None
# SD_gamma_air_line_25      0.09     -inf      inf        0    False     None     None
# SD_gamma_air_line_26       0.1     -inf      inf        0    False     None     None
# Temperature_1_1          297.9     -inf      inf        0    False     None     None
# Temperature_2_1          297.9     -inf      inf        0    False     None     None
# Temperature_3_1          297.9     -inf      inf        0    False     None     None
# Temperature_4_1          297.9     -inf      inf        0    False     None     None
# baseline_a_1_1           2.958     -inf      inf 6.189e-05     True     None     None
# baseline_a_2_1            2.96     -inf      inf 0.0004991     True     None     None
# baseline_a_3_1           2.953     -inf      inf 0.0005377     True     None     None
# baseline_a_4_1            2.95     -inf      inf 0.005363     True     None     None
# baseline_b_1_1        0.002043     -inf      inf 6.729e-05     True     None     None
# baseline_b_2_1        0.001943     -inf      inf 0.0005307     True     None     None
# baseline_b_3_1        0.001997     -inf      inf 0.0006057     True     None     None
# baseline_b_4_1        0.001798     -inf      inf 0.006461     True     None     None
# delta0_air_line_1     -0.007977     -inf      inf        0    False     None     None
# delta0_air_line_10    -0.007967     -inf      inf        0    False     None     None
# delta0_air_line_13    -0.008547     -inf      inf        0    False     None     None
# delta0_air_line_25    -0.008741     -inf      inf        0    False     None     None
# delta0_air_line_26    -0.008568     -inf      inf        0    False     None     None
# eta_air_line_1               0     -inf      inf        0    False     None     None
# eta_air_line_10              0     -inf      inf        0    False     None     None
# eta_air_line_13              0     -inf      inf        0    False     None     None
# eta_air_line_25              0     -inf      inf        0    False     None     None
# eta_air_line_26              0     -inf      inf        0    False     None     None
# etalon_1_amp_1_1      0.001676     -inf      inf  4.3e-05     True     None     None
# etalon_1_amp_2_1      0.001676     -inf      inf  4.3e-05    False etalon_1_amp_1_1     None
# etalon_1_amp_3_1      0.001676     -inf      inf  4.3e-05    False etalon_1_amp_1_1     None
# etalon_1_amp_4_1      0.001676     -inf      inf  4.3e-05    False etalon_1_amp_1_1     None
# etalon_1_period_1_1      1.271     -inf      inf        0    False     None     None
# etalon_1_period_2_1      1.271     -inf      inf        0    False     None     None
# etalon_1_period_3_1      1.271     -inf      inf        0    False     None     None
# etalon_1_period_4_1      1.271     -inf      inf        0    False     None     None
# etalon_1_phase_1_1     -0.7422     -inf      inf  0.02727     True     None     None
# etalon_1_phase_2_1      -0.476     -inf      inf    0.215     True     None     None
# etalon_1_phase_3_1      -1.385     -inf      inf   0.2514     True     None     None
# etalon_1_phase_4_1      -1.635     -inf      inf    2.362     True     None     None
# gamma0_air_line_1         0.04     -inf      inf        0    False     None     None
# gamma0_air_line_10      0.0447     -inf      inf 4.579e-05     True     None     None
# gamma0_air_line_13     0.04312     -inf      inf 6.094e-05     True     None     None
# gamma0_air_line_25        0.04     -inf      inf        0    False     None     None
# gamma0_air_line_26        0.04     -inf      inf        0    False     None     None
# molefraction_O2_1_1    0.01949     -inf      inf        0    False     None     None
# molefraction_O2_2_1    0.01949     -inf      inf        0    False     None     None
# molefraction_O2_3_1    0.01949     -inf      inf        0    False     None     None
# molefraction_O2_4_1    0.01949     -inf      inf        0    False     None     None
# nuVC_air_line_1              0     -inf      inf        0    False     None     None
# nuVC_air_line_10             0     -inf      inf        0    False     None     None
# nuVC_air_line_13             0     -inf      inf        0    False     None     None
# nuVC_air_line_25             0     -inf      inf        0    False     None     None
# nuVC_air_line_26             0     -inf      inf        0    False     None     None
# nu_1_line_1           1.315e+04 1.315e+04 1.315e+04        0    False     None     None
# nu_1_line_10          1.316e+04 1.316e+04 1.316e+04 0.0002993     True     None     None
# nu_1_line_13          1.316e+04 1.316e+04 1.316e+04 0.0002993     True     None     None
# nu_1_line_25          1.316e+04 1.316e+04 1.316e+04        0    False     None     None
# nu_1_line_26          1.316e+04 1.316e+04 1.316e+04        0    False     None     None
# nu_2_line_1           1.315e+04 1.315e+04 1.315e+04        0    False     None     None
# nu_2_line_10          1.316e+04 1.316e+04 1.316e+04 0.001663     True     None     None
# nu_2_line_13          1.316e+04 1.316e+04 1.316e+04 0.001662     True     None     None
# nu_2_line_25          1.316e+04 1.316e+04 1.316e+04        0    False     None     None
# nu_2_line_26          1.316e+04 1.316e+04 1.316e+04        0    False     None     None
# nu_3_line_1           1.315e+04 1.315e+04 1.315e+04        0    False     None     None
# nu_3_line_10          1.316e+04 1.316e+04 1.316e+04 0.001933     True     None     None
# nu_3_line_13          1.316e+04 1.316e+04 1.316e+04 0.001933     True     None     None
# nu_3_line_25          1.316e+04 1.316e+04 1.316e+04        0    False     None     None
# nu_3_line_26          1.316e+04 1.316e+04 1.316e+04        0    False     None     None
# nu_4_line_1           1.315e+04 1.315e+04 1.315e+04        0    False     None     None
# nu_4_line_10          1.316e+04 1.316e+04 1.316e+04  0.02722     True     None     None
# nu_4_line_13          1.316e+04 1.316e+04 1.316e+04   0.0272     True     None     None
# nu_4_line_25          1.316e+04 1.316e+04 1.316e+04        0    False     None     None
# nu_4_line_26          1.316e+04 1.316e+04 1.316e+04        0    False     None     None
# sw_1_line_1               4.37    2.185     8.74        0    False     None     None
# sw_1_line_10             4.729      2.4      9.6 0.0009732     True     None     None
# sw_1_line_13             3.085     1.56     6.24 0.0005988     True     None     None
# sw_1_line_25              2.08     1.04     4.16        0    False     None     None
# sw_1_line_26               3.4      1.7      6.8        0    False     None     None
# sw_2_line_1               4.37    2.185     8.74        0    False     None     None
# sw_2_line_10             4.749      2.4      9.6 0.005918     True     None     None
# sw_2_line_13              3.09     1.56     6.24 0.004815     True     None     None
# sw_2_line_25              2.08     1.04     4.16        0    False     None     None
# sw_2_line_26               3.4      1.7      6.8        0    False     None     None
# sw_3_line_1               4.37    2.185     8.74        0    False     None     None
# sw_3_line_10             4.743      2.4      9.6 0.007391     True     None     None
# sw_3_line_13             3.094     1.56     6.24 0.005834     True     None     None
# sw_3_line_25              2.08     1.04     4.16        0    False     None     None
# sw_3_line_26               3.4      1.7      6.8        0    False     None     None
# sw_4_line_1               4.37    2.185     8.74        0    False     None     None
# sw_4_line_10             4.798      2.4      9.6   0.1027     True     None     None
# sw_4_line_13             3.117     1.56     6.24  0.08486     True     None     None
# sw_4_line_25              2.08     1.04     4.16        0    False     None     None
# sw_4_line_26               3.4      1.7      6.8        0    False     None     None
# x_shift_1_1           0.0006743     -inf      inf 0.0002993     True     None     None
# x_shift_2_1           -0.002492     -inf      inf 0.001663     True     None     None
# x_shift_3_1           -0.0003981     -inf      inf 0.001933     True     None     None
# x_shift_4_1           -0.00296     -inf      inf  0.02722     True     None     None
# y_air_line_1                 0     -inf      inf        0    False     None     None
# y_air_line_10                0     -inf      inf        0    False     None     None
# y_air_line_13                0     -inf      inf        0    False     None     None
# y_air_line_25                0     -inf      inf        0    False     None     None
# y_air_line_26                0     -inf      inf        0    False     None     None
# None
